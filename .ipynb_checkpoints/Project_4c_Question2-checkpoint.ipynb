# %% [markdown]
# # Project 4
#
# ### Objectives
# 1. Determine the **industry factors** that are _most important_ in predicting the salary amounts for these data.
# 2. Determine the factors that distinguish job categories and titles from each other. For example, can required skills accurately predict job title?
#
# ### QUESTION 2: Factors that distinguish job category
#
# Using the job postings you scraped for part 1 (or potentially new job postings from a second round of scraping), identify features in the data related to job postings that can distinguish job titles from each other. There are a variety of interesting ways you can frame the target variable, for example:
# - What components of a job posting distinguish data scientists from other data jobs?
# - What features are important for distinguishing junior vs. senior positions?
# - Do the requirements for titles vary significantly with industry (e.g. healthcare vs. government)?
#
# You may end up making multiple classification models to tackle different questions. Be sure to clearly explain your hypotheses and framing, any feature engineering, and what your target variables are. The type of classification model you choose is up to you. Be sure to interpret your results and evaluate your models' performance.

# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
import re
import time

import matplotlib.pyplot as plt
import seaborn as sns

# %%
import nltk
from nltk.corpus import stopwords 
from nltk.stem.porter import PorterStemmer

from sklearn.pipeline import Pipeline
from sklearn.pipeline import make_pipeline
from sklearn.base import BaseEstimator, TransformerMixin

from sklearn.feature_extraction.text import CountVectorizer,TfidfTransformer
from sklearn.feature_selection import RFECV
from sklearn.model_selection import train_test_split,cross_val_score,GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import confusion_matrix, accuracy_score, recall_score, precision_score,classification_report,roc_curve, auc

# %%
df = pd.read_csv('./datasets/webscrape_alljobs_nosalary.csv',index_col=0)

# %%
df.head()
# Out:
#       Job_Company                                           Job_Desc  \
# 0  Morgan Stanley  Roles & Responsibilities COMPANY DESCRIPTION  ...
# 1          HP Inc  Roles & Responsibilities Review and understand...
# 2         Point72  Roles & ResponsibilitiesThe Analyst works toge...
# 3         Twitter  Roles & Responsibilities\r\n\r\n\r\n\r\n\r\n\r...
# 4          Henkel  Roles & ResponsibilitiesThe Development Techni...
#
#   Job_Salary                             Job_Title Job_employment_type  \
# 0       4500                      Business Analyst                 NaN
# 1       7100  Business Analyst /  Business Manager                 NaN
# 2       7000                      Business Analyst                 NaN
# 3       4250                      Business Analyst                 NaN
# 4       5000                      Technical Leader                 NaN
#
#    Min_years  Salary_max  Salary_min  Salary_avg
# 0        NaN      4500.0      4500.0      4500.0
# 1        NaN      7100.0      7100.0      7100.0
# 2        NaN      7000.0      7000.0      7000.0
# 3        NaN      4250.0      4250.0      4250.0
# 4        NaN      5000.0      5000.0      5000.0

# %%
df[df.duplicated(keep=False)].sort_values('Job_Title')
# Out:
#                               Job_Company  \
# 362            KERRY CONSULTING PTE. LTD.
# 43             KERRY CONSULTING PTE. LTD.
# 560            KERRY CONSULTING PTE. LTD.
# 429            KERRY CONSULTING PTE. LTD.
# 364                FINMECHANICS PTE. LTD.
# 281                FINMECHANICS PTE. LTD.
# 370  KELLY SERVICES (SINGAPORE) PTE. LTD.
# 569  KELLY SERVICES (SINGAPORE) PTE. LTD.
# 108  KELLY SERVICES (SINGAPORE) PTE. LTD.
# 164  KELLY SERVICES (SINGAPORE) PTE. LTD.
# 448  KELLY SERVICES (SINGAPORE) PTE. LTD.
# 236  KELLY SERVICES (SINGAPORE) PTE. LTD.
# 529  KELLY SERVICES (SINGAPORE) PTE. LTD.
# 269  KELLY SERVICES (SINGAPORE) PTE. LTD.
# 504  KELLY SERVICES (SINGAPORE) PTE. LTD.
# 455  KELLY SERVICES (SINGAPORE) PTE. LTD.
# 327        LOVEBONITO SINGAPORE PTE. LTD.
# 97         LOVEBONITO SINGAPORE PTE. LTD.
# 319              COMTEL SOLUTIONS PTE LTD
# 506              COMTEL SOLUTIONS PTE LTD
# 572                       MOZAT PTE. LTD.
# 557                       MOZAT PTE. LTD.
# 391                   Company Undisclosed
# 17                    Company Undisclosed
# 584                   Company Undisclosed
# 294                   Company Undisclosed
# 577           THATZ INTERNATIONAL PTE LTD
# 314           THATZ INTERNATIONAL PTE LTD
# 400              A*STAR RESEARCH ENTITIES
# 311              A*STAR RESEARCH ENTITIES
# 304              A*STAR RESEARCH ENTITIES
# 285              A*STAR RESEARCH ENTITIES
# 382              A*STAR RESEARCH ENTITIES
# 248              A*STAR RESEARCH ENTITIES
# 361              A*STAR RESEARCH ENTITIES
# 257              A*STAR RESEARCH ENTITIES
# 210              A*STAR RESEARCH ENTITIES
# 82               A*STAR RESEARCH ENTITIES
# 40               A*STAR RESEARCH ENTITIES
# 489                         HTZ RESOURCES
# 85                          HTZ RESOURCES
#
#                                               Job_Desc            Job_Salary  \
# 362  Roles & Responsibilities Global specialty chem...   $5000to$7500Monthly
# 43   Roles & Responsibilities Global specialty chem...   $5000to$7500Monthly
# 560  Roles & Responsibilities Global specialty chem...   $5000to$7500Monthly
# 429  Roles & Responsibilities Global specialty chem...   $5000to$7500Monthly
# 364  Roles & ResponsibilitiesYou Need to Be  A true...   $4500to$8000Monthly
# 281  Roles & ResponsibilitiesYou Need to Be  A true...   $4500to$8000Monthly
# 370  Roles & ResponsibilitiesWe are seeking a highl...   $4000to$6000Monthly
# 569  Roles & ResponsibilitiesWe are seeking a highl...   $5000to$7500Monthly
# 108  Roles & ResponsibilitiesWe are seeking a highl...   $5000to$7500Monthly
# 164  Roles & ResponsibilitiesWe are seeking a highl...   $6000to$9000Monthly
# 448  Roles & ResponsibilitiesWe are seeking a highl...   $4000to$6000Monthly
# 236  Roles & ResponsibilitiesWe are seeking a highl...   $6000to$9000Monthly
# 529  Roles & ResponsibilitiesWe are seeking a highl...   $3000to$4500Monthly
# 269  Roles & ResponsibilitiesWe are seeking a highl...   $3000to$4500Monthly
# 504  Roles & ResponsibilitiesWe are seeking a highl...   $5000to$7500Monthly
# 455  Roles & ResponsibilitiesWe are seeking a highl...   $6000to$9000Monthly
# 327  Roles & ResponsibilitiesThe role Youll have fr...   $3000to$6000Monthly
# 97   Roles & ResponsibilitiesThe role Youll have fr...   $3000to$6000Monthly
# 319  Roles & Responsibilities Perform full life-cyc...   $6500to$9750Monthly
# 506  Roles & Responsibilities Perform full life-cyc...   $6500to$9750Monthly
# 572  Roles & Responsibilities1. Participate in R&D ...   $3500to$5500Monthly
# 557  Roles & Responsibilities1. Participate in R&D ...   $3500to$5500Monthly
# 391  Roles & ResponsibilitiesWe are considering can...  $8000to$12000Monthly
# 17   Roles & ResponsibilitiesWe are considering can...   $4000to$8000Monthly
# 584  Roles & ResponsibilitiesWe are considering can...   $4000to$8000Monthly
# 294  Roles & ResponsibilitiesWe are considering can...  $8000to$12000Monthly
# 577  Roles & Responsibilities Gathers, analyzes and...   $3500to$4500Monthly
# 314  Roles & Responsibilities Gathers, analyzes and...   $3500to$4500Monthly
# 400  Roles & ResponsibilitiesAbout the Institute fo...   $2500to$5000Monthly
# 311  Roles & ResponsibilitiesAbout the Institute fo...   $2500to$5000Monthly
# 304  Roles & ResponsibilitiesAbout the Institute fo...   $2500to$5000Monthly
# 285  Roles & ResponsibilitiesAbout the Institute fo...   $2500to$5000Monthly
# 382  Roles & ResponsibilitiesAbout the Institute fo...   $4500to$9000Monthly
# 248  Roles & ResponsibilitiesAbout the Institute fo...   $4500to$9000Monthly
# 361  Roles & ResponsibilitiesAbout the Institute fo...   $4500to$9000Monthly
# 257  Roles & ResponsibilitiesAbout the Institute fo...   $4500to$9000Monthly
# 210  Roles & ResponsibilitiesAbout the Institute fo...   $4500to$9000Monthly
# 82   Roles & ResponsibilitiesAbout the Institute fo...   $4500to$9000Monthly
# 40   Roles & ResponsibilitiesAbout the Institute fo...   $4500to$9000Monthly
# 489  Roles & Responsibilities Define system-level a...  $6000to$10000Monthly
# 85   Roles & Responsibilities Define system-level a...  $6000to$10000Monthly
#
#                                              Job_Title   Job_employment_type  \
# 362         APAC Business Analyst  Specialty chemicals  Permanent, Full Time
# 43          APAC Business Analyst  Specialty chemicals  Permanent, Full Time
# 560         APAC Business Analyst  Specialty chemicals  Permanent, Full Time
# 429         APAC Business Analyst  Specialty chemicals  Permanent, Full Time
# 364                               Associate Consultant  Permanent, Full Time
# 281                               Associate Consultant  Permanent, Full Time
# 370                            BAU Analyst and Support              Contract
# 569                            BAU Analyst and Support              Contract
# 108                            BAU Analyst and Support              Contract
# 164                            BAU Analyst and Support              Contract
# 448                            BAU Analyst and Support              Contract
# 236                            BAU Analyst and Support              Contract
# 529                            BAU Analyst and Support              Contract
# 269                            BAU Analyst and Support              Contract
# 504                            BAU Analyst and Support              Contract
# 455                            BAU Analyst and Support              Contract
# 327                      Business Intelligence Analyst             Full Time
# 97                       Business Intelligence Analyst             Full Time
# 319                             Data Analytics Analyst   Contract, Full Time
# 506                             Data Analytics Analyst   Contract, Full Time
# 572                                      Data Engineer             Permanent
# 557                                      Data Engineer             Permanent
# 391                   Data Scientist, APAC (Singapore)             Full Time
# 17                    Data Scientist, APAC (Singapore)             Full Time
# 584                   Data Scientist, APAC (Singapore)             Full Time
# 294                   Data Scientist, APAC (Singapore)             Full Time
# 577               New Job Opening: IT Business Analyst             Full Time
# 314               New Job Opening: IT Business Analyst             Full Time
# 400  Research Engineer (Data Analytics)  /  I2R (A*...   Contract, Full Time
# 311  Research Engineer (Data Analytics)  /  I2R (A*...   Contract, Full Time
# 304  Research Engineer (Data Analytics)  /  I2R (A*...   Contract, Full Time
# 285  Research Engineer (Data Analytics)  /  I2R (A*...   Contract, Full Time
# 382  Scientist (Data Analytics /  Deep Learning)  /...   Contract, Full Time
# 248  Scientist (Data Analytics /  Deep Learning)  /...   Contract, Full Time
# 361        Scientist (Data Analytics)  /  I2R (A*STAR)   Contract, Full Time
# 257        Scientist (Data Analytics)  /  I2R (A*STAR)   Contract, Full Time
# 210        Scientist (Data Analytics)  /  I2R (A*STAR)   Contract, Full Time
# 82         Scientist (Data Analytics)  /  I2R (A*STAR)   Contract, Full Time
# 40         Scientist (Data Analytics)  /  I2R (A*STAR)   Contract, Full Time
# 489                                 Solution architect             Full Time
# 85                                  Solution architect             Full Time
#
#      Min_years  Salary_max  Salary_min  Salary_avg
# 362        NaN      7500.0      5000.0      6250.0
# 43         NaN      7500.0      5000.0      6250.0
# 560        NaN      7500.0      5000.0      6250.0
# 429        NaN      7500.0      5000.0      6250.0
# 364        NaN      8000.0      4500.0      6250.0
# 281        NaN      8000.0      4500.0      6250.0
# 370        NaN      6000.0      4000.0      5000.0
# 569        NaN      7500.0      5000.0      6250.0
# 108        NaN      7500.0      5000.0      6250.0
# 164        NaN      9000.0      6000.0      7500.0
# 448        NaN      6000.0      4000.0      5000.0
# 236        NaN      9000.0      6000.0      7500.0
# 529        NaN      4500.0      3000.0      3750.0
# 269        NaN      4500.0      3000.0      3750.0
# 504        NaN      7500.0      5000.0      6250.0
# 455        NaN      9000.0      6000.0      7500.0
# 327        NaN      6000.0      3000.0      4500.0
# 97         NaN      6000.0      3000.0      4500.0
# 319        NaN      9750.0      6500.0      8125.0
# 506        NaN      9750.0      6500.0      8125.0
# 572        NaN      5500.0      3500.0      4500.0
# 557        NaN      5500.0      3500.0      4500.0
# 391        NaN     12000.0      8000.0     10000.0
# 17         NaN      8000.0      4000.0      6000.0
# 584        NaN      8000.0      4000.0      6000.0
# 294        NaN     12000.0      8000.0     10000.0
# 577        NaN      4500.0      3500.0      4000.0
# 314        NaN      4500.0      3500.0      4000.0
# 400        NaN      5000.0      2500.0      3750.0
# 311        NaN      5000.0      2500.0      3750.0
# 304        NaN      5000.0      2500.0      3750.0
# 285        NaN      5000.0      2500.0      3750.0
# 382        NaN      9000.0      4500.0      6750.0
# 248        NaN      9000.0      4500.0      6750.0
# 361        NaN      9000.0      4500.0      6750.0
# 257        NaN      9000.0      4500.0      6750.0
# 210        NaN      9000.0      4500.0      6750.0
# 82         NaN      9000.0      4500.0      6750.0
# 40         NaN      9000.0      4500.0      6750.0
# 489        NaN     10000.0      6000.0      8000.0
# 85         NaN     10000.0      6000.0      8000.0

# %%
df.drop_duplicates(inplace=True)

# %%
df.reset_index(drop=True,inplace=True)

# %%
df['Job_Title_clean'] = ['Data Scientist' if 'scien' in jobtitle.lower() else 
                          'Data Analyst'    if 'data' in jobtitle.lower() and 'analy' in jobtitle.lower() else 
                          'Business Analyst'if 'business' in jobtitle.lower() else 
                          'Data Analyst'    if 'analy' in jobtitle.lower() else 
                          'Data Engineer'   if 'engineer' in jobtitle.lower() else
                          'other' for jobtitle in df['Job_Title']]

df['Job_Title_clean'].value_counts()
# Out:
# Business Analyst    644
# Data Scientist      233
# Data Engineer       226
# Data Analyst        198
# other               184
# Name: Job_Title_clean, dtype: int64

# %%
#downsample Business Analyst
ba_index = df[df['Job_Title_clean'] == 'Business Analyst'].index

# %%
import random 
newba_index = random.sample(ba_index,  220)
print len(newba_index)
# Out:
# 220

# %%
new_index = list(df[df['Job_Title_clean'] != 'Business Analyst'].index) + newba_index
len(new_index)
# Out:
# 1061

# %%
df.loc[new_index].shape
# Out:
# (1061, 10)

# %%
jobs = df.loc[new_index]

# %%
jobs['Job_Title_clean'].value_counts()
# Out:
# Data Scientist      233
# Data Engineer       226
# Business Analyst    220
# Data Analyst        198
# other               184
# Name: Job_Title_clean, dtype: int64

# %%
jobs['Job_Title_class'] = [0 if jobtitle == 'Data Scientist' else 
                           1 if jobtitle == 'Data Analyst'   else 
                           2 if jobtitle == 'Business Analyst'else 
                           3 if jobtitle == 'Data Engineer'   else
                           4 for jobtitle in jobs['Job_Title_clean']]

# %%
jobs['Job_Title_class'].value_counts()
# Out:
# 0    233
# 3    226
# 2    220
# 1    198
# 4    184
# Name: Job_Title_class, dtype: int64

# %%
jobs.shape
# Out:
# (1061, 11)

# %% [markdown]
# # Modelling

# %%
def obtain_scores(estimator,X_train, y_train, X_test, y_test):
    y_pred = estimator.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    ds_recall = recall_score(y_test, y_pred,average=None)[0]
    ds_precision = precision_score(y_test, y_pred,average=None)[0]
    ds_F1 = 2*(ds_precision*ds_recall)/(ds_precision+ds_recall)
    confusion = pd.DataFrame(confusion_matrix(y_test, y_pred), 
                             index=['is_{}'.format(name) for name in range(0,5)],
                             columns=['pred_{}'.format(name) for name in range(0,5)])
    
    fpr, tpr, _ = roc_curve(y_test, y_pred,pos_label=4)
    roc_auc = auc(fpr, tpr)

    print classification_report(y_test, y_pred)
    return {'confusion matrix': confusion,
            'roc': roc_auc,
            'for_compare': [accuracy,ds_recall,ds_precision,ds_F1,roc_auc]
           }

def add_model(model_name,summary,df):
    row = pd.DataFrame([model_name]+summary['for_compare'],
                       index=['model','accuracy','recall_DS','precision_DS','F1_score_DS','ROC']).T
    new_df = pd.concat([df,row])
    return new_df

# %%
X = jobs['Job_Desc']

    
X = X.map(lambda x: re.sub('[^ a-zA-Z]',' ',x).lower())
X = X.map(lambda x: " ".join(x.split())) 

to_replace_list = ['requirements', 'responsibilities','data']
for word in to_replace_list:
    X = X.str.replace(word, word +' ')

ps = PorterStemmer() 
# lemmatizer = WordNetLemmatizer()   
X = X.map(lambda x: ' '.join([ps.stem(word)for word in x.split() if word not in set(stopwords.words('english'))]))


X_train, X_test, y_train, y_test = train_test_split(X, 
                                                    jobs['Job_Title_class'], 
                                                    test_size = 0.25, 
                                                    random_state=42)

# %%
X_train.sample(5)
# Out:
# 836    role respons famili offic focus invest technol...
# 120    role respons job purpos softwar engin would pa...
# 956    role respons respons gather analyz document re...
# 736    role respons canopi http canopi cloud singapor...
# 193    role respons standard charter lead intern bank...
# Name: Job_Desc, dtype: object

# %%
y_train.sample(5)
# Out:
# 1346    3
# 1457    4
# 367     2
# 842     3
# 1227    0
# Name: Job_Title_class, dtype: int64

# %%
cvec = CountVectorizer()
cvec.fit_transform(X_train)
print len(cvec.get_feature_names())
# Out:
# 4317

# %%
#Set up empty dataframe to add results for easy comparison
summary = pd.DataFrame(columns=['model','accuracy','recall_DS','precision_DS','F1_score_DS','ROC'])

# %% [markdown]
# #### Using Logistic Regression

# %%
cvec = CountVectorizer()
logreg = LogisticRegression(penalty='l2')

pipe = Pipeline(steps=[('CountVec', cvec),
                       ('logreg',logreg)])
pipe.fit(X_train,y_train)
summary_pipe = obtain_scores(pipe,X_train,y_train,X_test,y_test)
summary = add_model('basic logreg penalty l2',summary_pipe,summary)
print summary_pipe['roc']
summary_pipe ['confusion matrix']
# Out:
#              precision    recall  f1-score   support
#
#           0       0.95      0.98      0.96        53
#           1       0.95      0.89      0.92        47
#           2       0.87      0.87      0.87        47
#           3       0.99      0.99      0.99        69
#           4       0.90      0.92      0.91        50
#
# avg / total       0.94      0.94      0.94       266
#
# 0.9497685185185185
#       pred_0  pred_1  pred_2  pred_3  pred_4
# is_0      52       0       0       1       0
# is_1       2      42       3       0       0
# is_2       1       1      41       0       4
# is_3       0       0       0      68       1
# is_4       0       1       3       0      46

# %%
cvec = CountVectorizer()
logreg = LogisticRegression(penalty='l2')

pipe = Pipeline(steps=[('CountVec', cvec),
                       ('logreg',logreg)])
pipe.fit(X_train,y_train)
summary_pipe = obtain_scores(pipe,X_train,y_train,X_test,y_test)
summary = add_model('basic logreg penalty l2',summary_pipe,summary)
print summary_pipe['roc']
summary_pipe ['confusion matrix']
# Out:
#              precision    recall  f1-score   support
#
#           0       0.95      0.98      0.96        53
#           1       0.95      0.89      0.92        47
#           2       0.87      0.87      0.87        47
#           3       0.99      0.99      0.99        69
#           4       0.90      0.92      0.91        50
#
# avg / total       0.94      0.94      0.94       266
#
# 0.9497685185185185
#       pred_0  pred_1  pred_2  pred_3  pred_4
# is_0      52       0       0       1       0
# is_1       2      42       3       0       0
# is_2       1       1      41       0       4
# is_3       0       0       0      68       1
# is_4       0       1       3       0      46

# %%
cvec = CountVectorizer()
tfidf = TfidfTransformer()
logreg = LogisticRegression(penalty='l1')

pipe = Pipeline(steps=[('CountVec', cvec),
                       ('tfidf',tfidf),
                       ('logreg',logreg)])
pipe.fit(X_train,y_train)
summary_pipe = obtain_scores(pipe,X_train,y_train,X_test,y_test)
print summary_pipe['roc']
summary = add_model('tfidf logreg penalty l1',summary_pipe,summary)
summary_pipe ['confusion matrix']
# Out:
#              precision    recall  f1-score   support
#
#           0       0.83      0.94      0.88        53
#           1       0.91      0.62      0.73        47
#           2       0.60      0.87      0.71        47
#           3       0.89      0.90      0.89        69
#           4       0.86      0.62      0.72        50
#
# avg / total       0.82      0.80      0.80       266
#
# 0.8362037037037037
#       pred_0  pred_1  pred_2  pred_3  pred_4
# is_0      50       1       2       0       0
# is_1       5      29      11       0       2
# is_2       0       1      41       3       2
# is_3       4       0       2      62       1
# is_4       1       1      12       5      31

# %%
cvec = CountVectorizer()
tfidf = TfidfTransformer()
logreg = LogisticRegression(penalty='l1')

pipe = Pipeline(steps=[('CountVec', cvec),
                       ('tfidf',tfidf),
                       ('logreg',logreg)])
pipe.fit(X_train,y_train)
summary_pipe = obtain_scores(pipe,X_train,y_train,X_test,y_test)
print summary_pipe['roc']
summary = add_model('tfidf logreg penalty l1',summary_pipe,summary)
summary_pipe ['confusion matrix']
# Out:
#              precision    recall  f1-score   support
#
#           0       0.83      0.94      0.88        53
#           1       0.91      0.62      0.73        47
#           2       0.60      0.87      0.71        47
#           3       0.89      0.90      0.89        69
#           4       0.86      0.62      0.72        50
#
# avg / total       0.82      0.80      0.80       266
#
# 0.8362037037037037
#       pred_0  pred_1  pred_2  pred_3  pred_4
# is_0      50       1       2       0       0
# is_1       5      29      11       0       2
# is_2       0       1      41       3       2
# is_3       4       0       2      62       1
# is_4       1       1      12       5      31

# %%
gs_params = {
                'penalty':['l1','l2'],
                'solver':['liblinear'],
                'C':np.logspace(-5,0,50),
                'tol':np.logspace(-5,0,10)
            }

lr_gridsearch = GridSearchCV(LogisticRegression(), gs_params, cv=5, verbose=1)
lr_gridsearch.fit(cvec.fit_transform(X_train), y_train)
# Out:
# Fitting 5 folds for each of 1000 candidates, totalling 5000 fits
# [Parallel(n_jobs=1)]: Done 5000 out of 5000 | elapsed:  7.5min finished
# GridSearchCV(cv=5, error_score='raise',
#        estimator=LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False),
#        fit_params=None, iid=True, n_jobs=1,
#        param_grid={'penalty': ['l1', 'l2'], 'C': array([1.00000e-05, 1.26486e-05, 1.59986e-05, 2.02359e-05, 2.55955e-05,
#        3.23746e-05, 4.09492e-05, 5.17947e-05, 6.55129e-05, 8.28643e-05,
#        1.04811e-04, 1.32571e-04, 1.67683e-04, 2.12095e-04, 2.68270e-04,
#        3.39322e-04, 4.29193e-04, 5.42868e-...,
#        5.99484e-03, 2.15443e-02, 7.74264e-02, 2.78256e-01, 1.00000e+00]), 'solver': ['liblinear']},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=None, verbose=1)

# %%
lr_gridsearch.best_estimator_
# Out:
# LogisticRegression(C=0.05963623316594643, class_weight=None, dual=False,
#           fit_intercept=True, intercept_scaling=1, max_iter=100,
#           multi_class='ovr', n_jobs=1, penalty='l2', random_state=None,
#           solver='liblinear', tol=0.021544346900318846, verbose=0,
#           warm_start=False)

# %%
cvec = CountVectorizer()
logreg = LogisticRegression(C=0.05963623316594643, class_weight=None, dual=False,
                              fit_intercept=True, intercept_scaling=1, max_iter=100,
                              multi_class='ovr', n_jobs=1, penalty='l2', random_state=None,
                              solver='liblinear', tol=0.021544346900318846, verbose=0,
                              warm_start=False)

pipe = Pipeline(steps=[('CountVec', cvec),
                       ('logreg',logreg)])
pipe.fit(X_train,y_train)
summary_pipe = obtain_scores(pipe,X_train,y_train,X_test,y_test)
print summary_pipe['roc']
summary = add_model('gridsearch logreg penalty l2',summary_pipe,summary)
summary_pipe ['confusion matrix']
# Out:
#              precision    recall  f1-score   support
#
#           0       0.95      0.98      0.96        53
#           1       0.95      0.89      0.92        47
#           2       0.87      0.87      0.87        47
#           3       0.97      0.99      0.98        69
#           4       0.90      0.90      0.90        50
#
# avg / total       0.93      0.93      0.93       266
#
# 0.9463425925925927
#       pred_0  pred_1  pred_2  pred_3  pred_4
# is_0      52       0       0       1       0
# is_1       2      42       3       0       0
# is_2       1       1      41       0       4
# is_3       0       0       0      68       1
# is_4       0       1       3       1      45

# %%
cvec = CountVectorizer()
tfidf = TfidfTransformer()
pipe = Pipeline(steps=[('CountVec', cvec),
                       ('tfidf',tfidf)])

gs_params = {
                'penalty':['l1','l2'],
                'solver':['liblinear'],
                'C':np.logspace(-5,0,50),
                'tol':np.logspace(-5,0,10)
            }

lr_gridsearch = GridSearchCV(LogisticRegression(), gs_params, cv=5, verbose=1)
lr_gridsearch.fit(pipe.fit_transform(X_train), y_train)
lr_gridsearch.best_estimator_
# Out:
# Fitting 5 folds for each of 1000 candidates, totalling 5000 fits
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-122-3fdd46b45cc8> in <module>()
#      12
#      13 lr_gridsearch = GridSearchCV(LogisticRegression(), gs_params, cv=5, verbose=1)
# ---> 14 lr_gridsearch.fit(pipe.fit_transform(X_train), y_train)
#      15 lr_gridsearch.best_estimator_
#
# C:\Users\ngyen\Anaconda2python2\lib\site-packages\sklearn\model_selection\_search.pyc in fit(self, X, y, groups, **fit_params)
#     637                                   error_score=self.error_score)
#     638           for parameters, (train, test) in product(candidate_params,
# --> 639                                                    cv.split(X, y, groups)))
#     640
#     641         # if one choose to see train score, "out" will contain train score info
#
# C:\Users\ngyen\Anaconda2python2\lib\site-packages\sklearn\externals\joblib\parallel.pyc in __call__(self, iterable)
#     777             # was dispatched. In particular this covers the edge
#     778             # case of Parallel used with an exhausted iterator.
# --> 779             while self.dispatch_one_batch(iterator):
#     780                 self._iterating = True
#     781             else:
#
# C:\Users\ngyen\Anaconda2python2\lib\site-packages\sklearn\externals\joblib\parallel.pyc in dispatch_one_batch(self, iterator)
#     618
#     619         with self._lock:
# --> 620             tasks = BatchedCalls(itertools.islice(iterator, batch_size))
#     621             if len(tasks) == 0:
#     622                 # No more tasks available in the iterator: tell caller to stop.
#
# C:\Users\ngyen\Anaconda2python2\lib\site-packages\sklearn\externals\joblib\parallel.pyc in __init__(self, iterator_slice)
#     125
#     126     def __init__(self, iterator_slice):
# --> 127         self.items = list(iterator_slice)
#     128         self._size = len(self.items)
#     129
#
# C:\Users\ngyen\Anaconda2python2\lib\site-packages\sklearn\model_selection\_search.pyc in <genexpr>((parameters, (train, test)))
#     636                                   return_times=True, return_parameters=False,
#     637                                   error_score=self.error_score)
# --> 638           for parameters, (train, test) in product(candidate_params,
#     639                                                    cv.split(X, y, groups)))
#     640
#
# C:\Users\ngyen\Anaconda2python2\lib\site-packages\sklearn\base.pyc in clone(estimator, safe)
#      58                             % (repr(estimator), type(estimator)))
#      59     klass = estimator.__class__
# ---> 60     new_object_params = estimator.get_params(deep=False)
#      61     for name, param in six.iteritems(new_object_params):
#      62         new_object_params[name] = clone(param, safe=False)
#
# C:\Users\ngyen\Anaconda2python2\lib\site-packages\sklearn\base.pyc in get_params(self, deep)
#     226         """
#     227         out = dict()
# --> 228         for key in self._get_param_names():
#     229             # We need deprecation warnings to always be on in order to
#     230             # catch deprecated param values.
#
# C:\Users\ngyen\Anaconda2python2\lib\site-packages\sklearn\base.pyc in _get_param_names(cls)
#     196         # introspect the constructor arguments to find the model parameters
#     197         # to represent
# --> 198         init_signature = signature(init)
#     199         # Consider the constructor parameters excluding 'self'
#     200         parameters = [p for p in init_signature.parameters.values()
#
# C:\Users\ngyen\Anaconda2python2\lib\site-packages\sklearn\externals\funcsigs.pyc in signature(obj)
#      60         if obj.__self__ is None:
#      61             # Unbound method: the first parameter becomes positional-only
# ---> 62             if sig.parameters:
#      63                 first = sig.parameters.values()[0].replace(
#      64                     kind=_POSITIONAL_ONLY)
#
# C:\Users\ngyen\Anaconda2python2\lib\site-packages\sklearn\externals\funcsigs.pyc in parameters(self)
#     585             return types.MappingProxyType(self._parameters)
#     586         except AttributeError:
# --> 587             return OrderedDict(self._parameters.items())
#     588
#     589     @property
#
# C:\Users\ngyen\Anaconda2python2\lib\collections.pyc in __init__(*args, **kwds)
#      67             root[:] = [root, root, None]
#      68             self.__map = {}
# ---> 69         self.__update(*args, **kwds)
#      70
#      71     def __setitem__(self, key, value, dict_setitem=dict.__setitem__):
#
# C:\Users\ngyen\Anaconda2python2\lib\_abcoll.pyc in update(*args, **kwds)
#     570             else:
#     571                 for key, value in other:
# --> 572                     self[key] = value
#     573         for key, value in kwds.items():
#     574             self[key] = value
#
# C:\Users\ngyen\Anaconda2python2\lib\collections.pyc in __setitem__(self, key, value, dict_setitem)
#      75         if key not in self:
#      76             root = self.__root
# ---> 77             last = root[0]
#      78             last[1] = root[0] = self.__map[key] = [last, root, key]
#      79         return dict_setitem(self, key, value)
#
# KeyboardInterrupt:

# %%
cvec = CountVectorizer()
logreg = LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
                              intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
                              penalty='l2', random_state=None, solver='liblinear',
                              tol=0.021544346900318846, verbose=0, warm_start=False)

pipe = Pipeline(steps=[('CountVec', cvec),
                       ('logreg',logreg)])
pipe.fit(X_train,y_train)
summary_pipe = obtain_scores(pipe,X_train,y_train,X_test,y_test)
print summary_pipe['roc']
summary = add_model('gridsearch logreg penalty l2',summary_pipe,summary)
summary_pipe ['confusion matrix']
# Out:
#              precision    recall  f1-score   support
#
#           0       0.95      0.98      0.96        53
#           1       0.95      0.89      0.92        47
#           2       0.87      0.87      0.87        47
#           3       0.99      0.99      0.99        69
#           4       0.90      0.92      0.91        50
#
# avg / total       0.94      0.94      0.94       266
#
# 0.9497685185185185
#       pred_0  pred_1  pred_2  pred_3  pred_4
# is_0      52       0       0       1       0
# is_1       2      42       3       0       0
# is_2       1       1      41       0       4
# is_3       0       0       0      68       1
# is_4       0       1       3       0      46

# %% [markdown]
# #### Using Naive Bayes

# %%
cvec = CountVectorizer()
bayes = MultinomialNB()

pipe = Pipeline(steps=[('CountVec', cvec),
                       ('bayes',bayes)])
pipe.fit(X_train,y_train)
summary_pipe = obtain_scores(pipe,X_train,y_train,X_test,y_test)
summary = add_model('bayes',summary_pipe,summary)
print summary_pipe['roc']
summary_pipe ['confusion matrix']
# Out:
#              precision    recall  f1-score   support
#
#           0       0.88      1.00      0.94        53
#           1       0.90      0.77      0.83        47
#           2       0.71      0.94      0.81        47
#           3       0.91      0.91      0.91        69
#           4       0.94      0.66      0.78        50
#
# avg / total       0.87      0.86      0.86       266
#       pred_0  pred_1  pred_2  pred_3  pred_4
# is_0      53       0       0       0       0
# is_1       2      36       5       3       1
# is_2       0       1      44       1       1
# is_3       4       2       0      63       0
# is_4       1       1      13       2      33

# %%
cvec = CountVectorizer()
tfidf = TfidfTransformer()
bayes = MultinomialNB()

pipe = Pipeline(steps=[('CountVec', cvec),
                       ('tfidf',tfidf),
                       ('bayes',bayes)])
pipe.fit(X_train,y_train)
summary_pipe = obtain_scores(pipe,X_train,y_train,X_test,y_test)
summary = add_model('tfidf bayes',summary_pipe,summary)
print summary_pipe['roc']
summary_pipe ['confusion matrix']
# Out:
#              precision    recall  f1-score   support
#
#           0       0.79      1.00      0.88        53
#           1       1.00      0.66      0.79        47
#           2       0.62      0.98      0.76        47
#           3       0.94      0.87      0.90        69
#           4       0.97      0.58      0.72        50
#
# avg / total       0.87      0.82      0.82       266
#
# 0.8147222222222222
#       pred_0  pred_1  pred_2  pred_3  pred_4
# is_0      53       0       0       0       0
# is_1       5      31      10       1       0
# is_2       0       0      46       1       0
# is_3       7       0       1      60       1
# is_4       2       0      17       2      29

# %% [markdown]
# ### Using Decision Trees

# %%
cvec = CountVectorizer()
tree = DecisionTreeClassifier(random_state=0)

pipe = Pipeline(steps=[('CountVec', cvec),
                       ('decision tree',tree)])
pipe.fit(X_train,y_train)
summary_pipe = obtain_scores(pipe,X_train,y_train,X_test,y_test)
summary = add_model('decision tree',summary_pipe,summary)
print summary_pipe['roc']
summary_pipe ['confusion matrix']
# Out:
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97        53
#           1       0.86      0.91      0.89        47
#           2       0.80      0.83      0.81        47
#           3       0.93      0.93      0.93        69
#           4       0.86      0.76      0.81        50
#
# avg / total       0.89      0.89      0.89       266
#
# 0.8964814814814814
#       pred_0  pred_1  pred_2  pred_3  pred_4
# is_0      52       0       0       1       0
# is_1       0      43       0       2       2
# is_2       0       7      39       0       1
# is_3       2       0       0      64       3
# is_4       0       0      10       2      38

# %%
cvec = CountVectorizer()
tfidf = TfidfTransformer()
tree = DecisionTreeClassifier(random_state=0)

pipe = Pipeline(steps=[('CountVec', cvec),
                       ('tfidf',tfidf),
                       ('decision tree',tree)])
pipe.fit(X_train,y_train)
summary_pipe = obtain_scores(pipe,X_train,y_train,X_test,y_test)
summary = add_model('tfidf decision tree',summary_pipe,summary)
print summary_pipe['roc']
summary_pipe ['confusion matrix']
# Out:
#              precision    recall  f1-score   support
#
#           0       0.83      1.00      0.91        53
#           1       0.83      0.85      0.84        47
#           2       0.95      0.79      0.86        47
#           3       0.94      0.91      0.93        69
#           4       0.79      0.76      0.78        50
#
# avg / total       0.87      0.87      0.87       266
#
# 0.8398611111111112
#       pred_0  pred_1  pred_2  pred_3  pred_4
# is_0      53       0       0       0       0
# is_1       1      40       1       1       4
# is_2       1       2      37       1       6
# is_3       6       0       0      63       0
# is_4       3       6       1       2      38

# %% [markdown]
# ### Using RFECV on logreg

# %%
cvec = CountVectorizer()
logreg = LogisticRegression(penalty='l2')
rfecv = RFECV(logreg, step=10, cv=3)

pipe = Pipeline(steps=[('CountVec', cvec),
                       ('rfecv',rfecv)])
pipe.fit(X_train,y_train)
summary_pipe = obtain_scores(pipe,X_train,y_train,X_test,y_test)
summary = add_model('rfecv logreg penalty l2',summary_pipe,summary)
print summary_pipe['roc']
summary_pipe ['confusion matrix']
# Out:
#              precision    recall  f1-score   support
#
#           0       0.95      0.98      0.96        53
#           1       0.95      0.89      0.92        47
#           2       0.87      0.87      0.87        47
#           3       0.99      0.99      0.99        69
#           4       0.90      0.92      0.91        50
#
# avg / total       0.94      0.94      0.94       266
#
# 0.9497685185185185
#       pred_0  pred_1  pred_2  pred_3  pred_4
# is_0      52       0       0       1       0
# is_1       2      42       3       0       0
# is_2       1       1      41       0       4
# is_3       0       0       0      68       1
# is_4       0       1       3       0      46

# %%
cvec = CountVectorizer()
logreg = LogisticRegression(penalty='l1')
rfecv = RFECV(logreg, step=10, cv=3)

pipe = Pipeline(steps=[('CountVec', cvec),
                       ('rfecv',rfecv)])
pipe.fit(X_train,y_train)
summary_pipe = obtain_scores(pipe,X_train,y_train,X_test,y_test)
summary = add_model('rfecv logreg penalty l1',summary_pipe,summary)
print summary_pipe['roc']
summary_pipe ['confusion matrix']
# Out:
#              precision    recall  f1-score   support
#
#           0       0.93      0.98      0.95        53
#           1       0.86      0.91      0.89        47
#           2       0.91      0.85      0.88        47
#           3       1.00      0.94      0.97        69
#           4       0.86      0.88      0.87        50
#
# avg / total       0.92      0.92      0.92       266
#
# 0.9221296296296296
#       pred_0  pred_1  pred_2  pred_3  pred_4
# is_0      52       1       0       0       0
# is_1       2      43       1       0       1
# is_2       1       1      40       0       5
# is_3       1       2       0      65       1
# is_4       0       3       3       0      44

# %% [markdown]
# ### Analysis on 'coefficients'

# %%
summary.reset_index(drop=True).sort_values('ROC',ascending = False)
# Out:
#                            model  accuracy recall_DS precision_DS F1_score_DS  \
# 0        basic logreg penalty l2   0.93609  0.981132     0.945455    0.962963
# 1        basic logreg penalty l2   0.93609  0.981132     0.945455    0.962963
# 8        rfecv logreg penalty l2   0.93609  0.981132     0.945455    0.962963
# 4   gridsearch logreg penalty l2  0.932331  0.981132     0.945455    0.962963
# 9        rfecv logreg penalty l2  0.917293  0.981132     0.928571    0.954128
# 6                  decision tree  0.887218  0.981132     0.962963    0.971963
# 3        tfidf logreg penalty l2  0.887218         1     0.898305    0.946429
# 7            tfidf decision tree  0.868421         1     0.828125    0.905983
# 2        tfidf logreg penalty l1  0.800752  0.943396     0.833333    0.884956
# 10       tfidf logreg penalty l1  0.800752  0.943396     0.833333    0.884956
# 5                    tfidf bayes  0.823308         1     0.791045    0.883333
#
#          ROC
# 0   0.949769
# 1   0.949769
# 8   0.949769
# 4   0.946343
# 9    0.92213
# 6   0.896481
# 3    0.87713
# 7   0.839861
# 2   0.836204
# 10  0.836204
# 5   0.814722

# %%
cvec = CountVectorizer()
tfidf = TfidfTransformer()
logreg = LogisticRegression(penalty='l2')

X_train_new = cvec.fit_transform(X_train)
X_train_new = tfidf.fit_transform(X_train_new)
logreg.fit(X_train_new,y_train)

pd.DataFrame([abs(logreg.coef_[0]),logreg.coef_[0]],
             columns=cvec.get_feature_names(),
             index=['abs_coefficient','coefficent']).T.\
             sort_values('abs_coefficient',ascending=False)
# Out:
#            abs_coefficient  coefficent
# learn             2.763041    2.763041
# machin            2.268495    2.268495
# model             2.014537    2.014537
# statist           1.955771    1.955771
# manag             1.608839   -1.608839
# research          1.435420    1.435420
# report            1.421285   -1.421285
# phd               1.382348    1.382348
# data              1.330662    1.330662
# scienc            1.310000    1.310000
# ml                1.260327    1.260327
# algorithm         1.230957    1.230957
# hadoop            1.156577    1.156577
# ai                1.103548    1.103548
# scientist         1.078404    1.078404
# appli             1.058617    1.058617
# client            1.037017   -1.037017
# system            1.024598   -1.024598
# strong            0.979796   -0.979796
# analyst           0.976445   -0.976445
# aa                0.960361    0.960361
# analyz            0.954965   -0.954965
# mathemat          0.916633    0.916633
# languag           0.883260    0.883260
# busi              0.874849   -0.874849
# python            0.813495    0.813495
# ensur             0.812245   -0.812245
# mufg              0.800481    0.800481
# perform           0.799948   -0.799948
# insight           0.790293    0.790293
# ...                    ...         ...
# prespect          0.002498   -0.002498
# opentext          0.002498   -0.002498
# workload          0.002299    0.002299
# primari           0.002283    0.002283
# punctual          0.002259   -0.002259
# moral             0.002259   -0.002259
# mca               0.002259   -0.002259
# frequent          0.002224    0.002224
# dba               0.002197    0.002197
# label             0.002034    0.002034
# broader           0.002029    0.002029
# pressur           0.002022   -0.002022
# quantiti          0.001855   -0.001855
# scenario          0.001800    0.001800
# aspir             0.001484   -0.001484
# vanilla           0.001464   -0.001464
# hedg              0.001313    0.001313
# rabbitmq          0.001261    0.001261
# san               0.001217    0.001217
# quant             0.001080    0.001080
# underwrit         0.000908    0.000908
# teach             0.000835   -0.000835
# reconcili         0.000752   -0.000752
# hdf               0.000728    0.000728
# concept           0.000691   -0.000691
# first             0.000579   -0.000579
# stake             0.000469   -0.000469
# supplier          0.000421   -0.000421
# measur            0.000233   -0.000233
# employ            0.000153   -0.000153
#
# [4317 rows x 2 columns]

# %%
pd.DataFrame(abs(logreg.coef_),columns = cvec.get_feature_names(), 
             index = logreg.classes_)\
            .T.sort_values('Data Scientist',ascending = False)

# %%
cvec = CountVectorizer()
logreg = LogisticRegression(penalty='l1')
rfecv = RFECV(logreg, step=10, cv=3)

X_train_new = cvec.fit_transform(X_train)
rfecv.fit(X_train_new,y_train)
summary_pipe = obtain_scores(pipe,X_train,y_train,X_test,y_test)
print summary_pipe['roc']
summary_pipe ['confusion matrix']
# Out:
#              precision    recall  f1-score   support
#
#           0       0.83      0.94      0.88        53
#           1       0.91      0.62      0.73        47
#           2       0.60      0.87      0.71        47
#           3       0.89      0.90      0.89        69
#           4       0.86      0.62      0.72        50
#
# avg / total       0.82      0.80      0.80       266
#
# 0.8362037037037037
#       pred_0  pred_1  pred_2  pred_3  pred_4
# is_0      50       1       2       0       0
# is_1       5      29      11       0       2
# is_2       0       1      41       3       2
# is_3       4       0       2      62       1
# is_4       1       1      12       5      31

# %%
rfecv_columns = np.array(cvec.get_feature_names())[rfecv.support_]
X_train_best = X_train.map(lambda x: ' '.join([word for word in x.split() if word in rfecv_columns]))

# %%
cvec = CountVectorizer()
logreg = LogisticRegression(penalty='l1')

X_train_new = cvec.fit_transform(X_train_best)
logreg.fit(X_train_new,y_train)

pd.DataFrame([abs(logreg.coef_[0]),logreg.coef_[0]],
             columns=cvec.get_feature_names(),
             index=['abs_coefficient','coefficent']).T.\
             sort_values('abs_coefficient',ascending=False).head(20)
# Out:
#            abs_coefficient  coefficent
# phd               2.597537    2.597537
# hadoop            1.919791    1.919791
# high              1.348101   -1.348101
# analyz            1.329823   -1.329823
# engin             1.293707   -1.293707
# travel            1.235036    1.235036
# minimum           1.162412   -1.162412
# scientist         1.036516    1.036516
# cognit            1.016169    1.016169
# mufg              0.998309    0.998309
# plan              0.884280   -0.884280
# cloud             0.830475   -0.830475
# report            0.816908   -0.816908
# specif            0.752772   -0.752772
# farm              0.735450    0.735450
# strong            0.702021   -0.702021
# manag             0.665042   -0.665042
# analyst           0.643112   -0.643112
# learn             0.617586    0.617586
# creat             0.595811    0.595811

# %% [markdown]
# # Conclusion
# What components of a job posting distinguish data scientists from other data jobs?
# - score of all the metrics (accuracy, precision, recall, f1 score) is very good
# - which means that the job description does reflect the job-title
# - words like phd, hadoop,analyze,engineer,travel plays a big importance in the type of job there is.
